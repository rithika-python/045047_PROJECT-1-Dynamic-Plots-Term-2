# %%
# install bubbly for plotting bubble plots
# !pip install bubbly
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bubbly: filename=bubbly-1.0.2-py3-none-any.whl size=5415 sha256=a0855a494f353d3512b69e19726ab7accea39b83dd3dcf7a80c4a0e41a6a745c
#   Stored in directory: /root/.cache/pip/wheels/dc/b4/ab/043c77f064dbbb38983593a3bed54363cc1910d0fb20ba6f66
# Successfully built bubbly
# ...

# %%
# import basic libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.offline as py
import bubbly
from bubbly.bubbly import bubbleplot

# %%
df = pd.read_csv("us-population-2010-2019-reshaped.csv")
df
# Out:
#      Unnamed: 0         states states_code  id  year  population
# 0             0        Alabama          AL   1  2010     4785437
# 1             1         Alaska          AK   2  2010      713910
# 2             2        Arizona          AZ   4  2010     6407172
# 3             3       Arkansas          AR   5  2010     2921964
# 4             4     California          CA   6  2010    37319502
# ..          ...            ...         ...  ..   ...         ...
# 515         515     Washington          WA  53  2019     7614893
# 516         516  West Virginia          WV  54  2019     1792147
# 517         517      Wisconsin          WI  55  2019     5822434
# 518         518        Wyoming          WY  56  2019      578759
# 519         519    Puerto Rico          PR  72  2019     3193694
#
# [520 rows x 6 columns]

# %%
import plotly.express as px
px.scatter(df, x="year", y="population", animation_frame="year", animation_group="states",size="population", color="states", hover_name="states",log_x=True, size_max=500, range_x=[1000,50000], range_y=[10000,10000000000000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Graph 1 (Scatter Plot Animation):**
#
# **1. OBJECTIVES:**
# * To visualize the population trends of different states over time in an animated and interactive format.
# * To compare population growth rates and trajectories among states.
# * To highlight any significant changes or patterns in population distribution.
#
# ---
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. ANALYSIS:**
# * Tracks population changes dynamically over time, making trends more visually engaging and easier to grasp.
# * Each state's population trajectory is represented by a separate path, allowing for clear comparison between states.
# * Accommodates the wide range of population values while maintaining visual clarity.
# * Represents population size intuitively, with larger circles indicating larger populations.
# * Differentiates states visually and makes tracking individual paths easier.
# * Provides additional information (state name) when hovering over data points.
#
# ----
#
# **4. MANAGERIAL IMPLICATIONS/INTERPRETATION:**
# * Population growth: The overall trend appears to be positive, suggesting population growth across most states.
# * Varying growth rates: The slopes of the paths differ, indicating varying growth rates among states. Some states may be experiencing faster growth than others.
# * Notable outliers: States with significantly larger or smaller populations may stand out visually, suggesting potential demographic distinctions.
# * Significant events: Correlate population changes with historical events or policy changes that might have impacted population growth.
# ----

# %%
import pandas as pd
import plotly.express as px

# Assuming your CSV file has columns: 'year', 'population', 'states'
df = pd.read_csv("us-population-2010-2019-reshaped.csv")

fig = px.bar(
    df,
    x="states_code",
    y="population",
    animation_frame="year",  # Specify the 'year' column for animation
    color="states",
    hover_name="states",
    labels={"population": "Population", "year": "Year", "states_code": "States Code"},
    title="US Population Over Time",
)

fig.update_layout(
    xaxis_title="States",
    yaxis_title="Population",
    showlegend=True,
    legend_title_text="States",
    yaxis=dict(
        range=[0, 40000000],  # Adjust the range of the y-axis based on your preference
    ),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Graph 2 (Animated Bar Chart):**
#
# **1. OBJECTIVES:**
# * To visualize the population changes in different US states over time, from 2010 to 2019, using an animated bar chart.
# * To compare population sizes and growth rates among states visually.
# * To identify any significant trends or patterns in population distribution across states.
#
# ---
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. ANALYSIS:**
#
# * Animated bar chart: Bars represent states' populations, with heights changing dynamically over time to showcase population shifts.
# * States arranged on the x-axis: Allows for visual comparison of populations across states.
# * Color-coded bars by state: Distinguishes states for easier tracking and comparison.
# * Interactive hover feature: Reveals state names and population values upon hovering, enabling focused exploration.
# * Years as animation frames: Creates a visual "play" button to observe population changes through time.
# * Customizable y-axis range: Focuses the view on specific population ranges.
#
# ----
#
# **4. MANAGERIAL IMPLICATIONS/INTERPRETATION:**
# * Population growth trends: Assess overall growth patterns (e.g., steady, exponential, decline) across states and identify any outliers with distinct trajectories.
# * Relative population sizes: Compare states' populations visually and identify the most populous and least populous ones.
# * Population shifts: Observe changes in states' relative positions over time, potentially indicating migration patterns or other factors influencing population distribution.
# * Significant events: Correlate population changes with historical events or policy changes that might have impacted population growth.
#
# ---

# %%
import pandas as pd
import plotly.express as px

# Assuming your CSV file has columns: 'year', 'population', 'states'
df = pd.read_csv("us-population-2010-2019-reshaped.csv")

# Choose any 5 states you are interested in
selected_states = ["California", "Texas", "New York", "Florida", "Illinois"]

# Filter the DataFrame for the selected states
filtered_df = df[df["states"].isin(selected_states)]

fig = px.bar(
    filtered_df,
    x="states_code",
    y="population",
    animation_frame="year",  # Specify the 'year' column for animation
    color="states",
    hover_name="states",
    labels={"population": "Population", "year": "Year", "states_code": "States Code"},
    title="US Population Over Time (Selected States)",
)

fig.update_layout(
    xaxis_title="States",
    yaxis_title="Population",
    showlegend=True,
    legend_title_text="States",
    yaxis=dict(
        range=[40000000, 10000000],  # Adjust the range of the y-axis based on your preference
    ),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Graph 3 (Selected States Bar Chart):**
#
# **1. OBJECTIVES:**
# * To visualize and compare population trends of five specific states (California, Texas, New York, Florida, Illinois) from 2010 to 2019 using an animated bar chart.
# * To highlight any significant changes or patterns in population growth within these states.
# * To enable focused exploration of population dynamics within a selected subset of states.
#
# ---
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. ANALYSIS:**
#
# * Animated bar chart: Bars represent states' populations, with heights changing over time to showcase population shifts.
# * Five selected states on the x-axis: Allows for visual comparison of populations within this specific group.
# * Color-coded bars by state: Distinguishes states for easier tracking.
# Interactive hover feature: Reveals state names and population values upon hovering.
# * Years as animation frames: Creates a visual "play" button to observe population changes through time.
# * Customizable y-axis range: Focuses the view on the 40-50 million population range.
#
# ---
#
# **4. MANAGERIAL IMPLICATIONS/INTERPRETATION:**
# * Population growth trends: Assess growth patterns (steady, exponential, decline) within the selected states and identify any outliers.
# * Relative population sizes: Compare populations visually and identify the most populous state within this group.
# * Population shifts: Observe changes in states' relative positions over time, potentially indicating migration or other factors.
# * Significant events: Correlate population changes with historical events or policies that might have impacted growth.
#
# ---

# %%
import pandas as pd
import plotly.graph_objects as go

# Assuming your CSV file has columns: 'year', 'population', 'states'
df = pd.read_csv("us-population-2010-2019-reshaped.csv")

# Choose the 5 states you are interested in
selected_states = ["Kansas", "Iowa", "New York", "Idaho", "Mississippi"]

# Filter the DataFrame for the selected states
filtered_df = df[df["states"].isin(selected_states)]

# Set a base year for comparison
base_year = 2010

fig = go.Figure()

for state in selected_states:
    state_data = filtered_df[filtered_df["states"] == state]
    population_diff = state_data["population"] - state_data[state_data["year"] == base_year]["population"].values[0]
    trace = go.Scatter(
        x=state_data["year"],
        y=population_diff,
        mode='lines+markers',
        name=state
    )
    fig.add_trace(trace)

fig.update_layout(
    xaxis_title="Year",
    yaxis_title="Population Difference (vs. {})".format(base_year),
    title="Change in Population Over Time (Selected States)",
    showlegend=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Graph 4 (Population Difference Over Time):**
#
# **1. OBJECTIVES:**
# * To visualize and compare population changes over time for five specific states (Kansas, Iowa, New York, Idaho, Mississippi) relative to a base year (2010).
# * To highlight any significant trends or patterns in population growth or decline within these states.
#
# ---
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. ANALYSIS:**
# * Multiple line plots: Each line represents the population change for a specific state, with markers indicating data points for each year.
# * Years on the x-axis: Allows for tracking population changes over time.
# * Population difference on the y-axis: Measures the change in population relative to the base year (2010), indicating growth or decline.
# * Color-coded lines: Distinguishes states for easier comparison.
# * Interactive features (likely): Plotly often includes hover features to reveal specific values upon hovering over data points.
#
# ---
#
# **4. MANAGERIAL IMPLICATIONS/INTERPRETATION:**
# * Overall trends: Describe the general patterns of population change for each state (e.g., steady growth, decline, fluctuations).
# * States with the most significant changes: Identify states that have experienced the largest population increases or decreases relative to the base year.
# * Years with notable shifts: Point out any years where population changes were particularly prominent for any states.
# * Crossings of lines: Indicate if any lines cross, suggesting a change in relative population growth between states.
#
# ---

# %%
import pandas as pd
import plotly.express as px

# Assuming your CSV file has columns: 'year', 'population', 'states'
df = pd.read_csv("us-population-2010-2019-reshaped.csv")

# Choose any 5 states you are interested in
selected_states = ["Oklahoma", "Maryland", "Utah", "Tennessee", "Puerto Rico"]

# Filter the DataFrame for the selected states
filtered_df = df[df["states"].isin(selected_states)]

fig = px.bar(
    filtered_df,
    x="states_code",
    y="population",
    animation_frame="year",  # Specify the 'year' column for animation
    color="states",
    hover_name="states",
    labels={"population": "Population", "year": "Year", "states_code": "States Code"},
    title="US Population Over Time (Selected States)",
)

fig.update_layout(
    xaxis_title="States",
    yaxis_title="Population",
    showlegend=True,
    legend_title_text="States",
    yaxis=dict(
        range=[1000000, 8000000],  # Adjust the range of the y-axis based on your preference
    ),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Graph 5 (Selected States Population Bar Chart):**
#
# **1. OBJECTIVES:**
# * To visualize and compare population trends of five specific states (Oklahoma, Maryland, Utah, Tennessee, Puerto Rico) from 2010 to 2019.
# * To highlight any significant changes or patterns in population growth within these states over time.
# * To enable focused exploration of the population dynamics within this selected subset of states.
# ---
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. ANALYSIS:**
# * Animated bar chart: The graph uses animated bars to represent the populations of each state, with bar heights dynamically changing over time to showcase population shifts.
# * Five selected states on the x-axis: The states are arranged on the x-axis, allowing for visual comparison of their populations.
# * Color-coded bars: Each state is assigned a distinct color, making it easier to track their individual trends.
# * Interactive hover feature: Users can hover over bars to reveal the specific state name and population value for that year.
# * Years as animation frames: The graph animates through the years, creating a visual "play" button to observe population changes as they unfold.
# * Customizable y-axis range: The y-axis is focused on a range of 1 million to 8 million, adjusting the view to the relevant population scale.
# ____
# **4. MANAGERIAL IMPLICATIONS/INTERPRETATION:**
#
# * Overall population trends: Describe the general patterns of population change for each state (e.g., steady growth, decline, fluctuations).
# * States with the largest populations: Identify which states have the highest populations overall.
# * States with the most significant population changes: Point out which states have experienced the largest increases or decreases in population over the decade.
# * Years with notable shifts: Indicate if there are any years where population changes were particularly prominent for any states.
# * Comparisons between states: Analyze how the population trends of these states compare with each other.
# ___

# %% [markdown]
# **PROJECT REPORT**
#
#
# **DATA OVERVIEW:**
#
# The data you have shows the population of different states in the United States from 2010 to 2019. Each row represents a state and includes details like the state's name, a two-letter code, a unique identifier, the year of recording, and the population count for that year. This information helps you understand how the population of each state has changed over the years. The dataset is handy for researchers and policymakers, providing insights into demographic trends and supporting informed decision-making for various purposes.
#
#
#
# **1. OBJECTIVES:**
#
# **A. Graph 1 (Scatter Plot Animation):**
#
# * Visualize the population trends across different states in the US from 2010 to 2019.
# * Explore how population size varies over time, considering a log scale for the x-axis.
#
# **B. Graph 2 (Animated Bar Chart):**
# *Illustrate the population changes in US states over the years through a bar chart animation.
# * Focus on presenting the population distribution dynamically.
#
# **C. Graph 3 (Selected States Bar Chart):**
# * Analyze the population trends of specific states (California, Texas, New York, Florida, Illinois).
# * Highlight how the selected states compare in population over the specified years.
#
# **D. Graph 4 (Population Difference Over Time):**
# * Examine how the populations of specific states (Kansas, Iowa, New York, Idaho, Mississippi) changed relative to the base year (2010).
# * Identify trends in population differences over the years.
#
# **E. Graph 5 (Selected States Population Bar Chart):**
# * Focus on the populations of specific states (Oklahoma, Maryland, Utah, Tennessee, Puerto Rico) over the years.
# * Observe how these states compare to each other in terms of population.
#
# ----
#
# **2. BRIEF OF DATA & ANALYSIS:**
#
# * The data used is from a CSV file containing information about the population of various US states from 2010 to 2019.
# * Different visualizations were created to analyze and present population trends, changes, and comparisons across states and years.
# * Various chart types, including scatter plots, bar charts, and line charts, were utilized to provide a comprehensive view of the data.
#
# ----
#
# **3. OBSERVATIONS:**
#
# Graph 1 (Scatter Plot Animation):
#
# The scatter plot animation effectively captures the population changes across all US states from 2010 to 2019. Each point represents a state, and the animation showcases how their populations evolve over time. The log scale on the x-axis allows for a clear view of both small and large population states. Notably, states with substantial population growth or decline are easily identifiable.
#
# ![image.png](data:image/png;base64,...)
#
# Graph 2 (Animated Bar Chart):
#
# The animated bar chart provides a dynamic representation of the population distribution across US states over the specified years. As the animation progresses, one can observe fluctuations in population sizes, helping to identify states with consistent growth or decline. The color-coded bars add clarity, making it easy to track changes in individual states over time.
#
# ![image.png](data:image/png;base64,...)
#
# Graph 3 (Selected States Bar Chart):
#
# The bar chart focusing on selected states (California, Texas, New York, Florida, Illinois) offers a detailed view of their population trends. California consistently stands out with the highest population, while the others vary in growth rates. This chart is valuable for comparing the chosen states and understanding their relative positions in terms of population over the years.
#
# ![image.png](data:image/png;base64,...)
#
#
# Graph 4 (Population Difference Over Time):
#
# This line chart illustrates the population difference of selected states (Kansas, Iowa, New York, Idaho, Mississippi) relative to the base year (2010). Positive values indicate population growth, while negative values imply a decline. The chart shows how states compare in terms of population changes, enabling a deeper understanding of trends over the specified period.
#
# ![image.png](data:image/png;base64,...)
#
# Graph 5 (Selected States Population Bar Chart):
#
# Focused on specific states (Oklahoma, Maryland, Utah, Tennessee, Puerto Rico), this bar chart reveals their population changes over time. Each state's population trajectory becomes apparent, and the color-coded bars make it easy to distinguish between them. Insights gained from this chart can aid in understanding the unique population dynamics of these selected states.
#
# ![image.png](data:image/png;base64,...)
#
# ----
#
# **4. MANAGERIAL IMPLICATIONS OR INSIGHTS**
#
# A. Graph 1 (Scatter Plot Animation):
#
# * The animation highlights the population growth trends in various states.
# * Useful for policy-makers to identify states with significant population increases.
#
#
# B. Graph 2 (Animated Bar Chart):
#
# * Provides a dynamic overview of population distribution changes in the US over the years.
# * Useful for understanding population dynamics for resource allocation and planning.
#
# C. Graph 3 (Selected States Bar Chart):
#
# * Managers can gain insights into how the populations of key states have evolved over the years.
# * Useful for businesses targeting specific states for expansion.
#
#
# D. Graph 4 (Population Difference Over Time):
#
# * Identifies states that experienced higher-than-average population growth relative to the base year.
# * Can guide resource allocation for states with significant population changes.
#
#
# E. Graph 5 (Selected States Population Bar Chart):
#
# * Offers a focused view of population trends in selected states.
# Valuable for decision-makers focusing on specific states for strategic planning.
#
#
# Conclusion:
# The combination of these visualizations provides a comprehensive understanding of population dynamics in the US over the specified years. The insights gained can inform decision-making processes for policymakers, businesses, and other stakeholders.
#
# ----

# %% [markdown]
# **SOURCE OF THE DATA:** https://www.census.gov/data/datasets/time-series/demo/popest/2010s-state-total.html & ChatGPT
#
# US Population data spanning the duration of 2010-2019 was obtained from the U.S. Census Bureau.
